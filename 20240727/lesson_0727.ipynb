# %%
print(100,12,10,11,sep="/")
print(10,11,10,11,sep="/",end=".")
print()

name = '123'
chinese = 78
english = 89.0
math = 65.0
print(name,chinese,english,math)
print(type(name))
print(type(chinese))
print(type(english))
# Out:
# 100/12/10/11
# 10/11/10/11.
# 123 78 89.0 65.0
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
### IF Else

num = int (input())
if num <10:
    print("true")
else:
    print("flase")
# Out:
# true

# %%
import random
A =  random.randint(1,10)

A
# Out:
# 9

# %%
a = 5  
b = 10
c = 3

print(a + b)
print(a + b // c)
print(a + b / c)
print(a * (b + c))
# Out:
# 15
# 8
# 65
